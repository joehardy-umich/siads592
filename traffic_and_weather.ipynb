# %%
import os
import pandas as pd
import altair as alt
import numpy as np

weather_data = pd.read_csv('clean_weather_data.csv')
covid_data = pd.read_csv('clean_covid_data.csv')

weather_data = weather_data.drop(weather_data.columns[0],axis=1)
covid_data = covid_data.drop(covid_data.columns[0],axis=1)

covid_data

weather_data

#We can compare average temperature to confirmed cases, deaths, and recoveries
merged_df = covid_data.merge(weather_data,how='inner',left_on=['ObservationDate','Province/State'],right_on=['date','location'])
merged_df['date'] = pd.to_datetime(merged_df['date'])
merged_df
# Out:
#           SNo ObservationDate Province/State Country/Region  \
# 0         163      2020-01-25       Illinois             US
# 1         208      2020-01-26       Illinois             US
# 2         209      2020-01-26     California             US
# 3         256      2020-01-27       Illinois             US
# 4         257      2020-01-27     California             US
# ...       ...             ...            ...            ...
# 12870  192089      2020-12-31       Virginia             US
# 12871  192098      2020-12-31     Washington             US
# 12872  192101      2020-12-31  West Virginia             US
# 12873  192103      2020-12-31      Wisconsin             US
# 12874  192104      2020-12-31        Wyoming             US
#
#                Last Update  Confirmed  Deaths  Recovered       date  \
# 0            1/25/20 17:00        1.0     0.0        0.0 2020-01-25
# 1            1/26/20 16:00        1.0     0.0        0.0 2020-01-26
# 2            1/26/20 16:00        2.0     0.0        0.0 2020-01-26
# 3            1/27/20 23:59        1.0     0.0        0.0 2020-01-27
# 4            1/27/20 23:59        2.0     0.0        0.0 2020-01-27
# ...                    ...        ...     ...        ...        ...
# 12870  2021-04-02 15:13:53   349584.0  5032.0        0.0 2020-12-31
# 12871  2021-04-02 15:13:53   246752.0  3461.0        0.0 2020-12-31
# 12872  2021-04-02 15:13:53    85334.0  1338.0        0.0 2020-12-31
# 12873  2021-04-02 15:13:53   520438.0  5242.0        0.0 2020-12-31
# 12874  2021-04-02 15:13:53    44409.0   438.0        0.0 2020-12-31
#
#        Average Temperature (deg F)       location     fids
# 0                        33.600000       Illinois  FIPS:17
# 1                        33.580000       Illinois  FIPS:17
# 2                        45.983280     California  FIPS:06
# 3                        30.400000       Illinois  FIPS:17
# 4                        45.399615     California  FIPS:06
# ...                            ...            ...      ...
# 12870                    48.800000       Virginia  FIPS:51
# 12871                    37.500000     Washington  FIPS:53
# 12872                    43.600000  West Virginia  FIPS:54
# 12873                    19.240000      Wisconsin  FIPS:55
# 12874                    23.466667        Wyoming  FIPS:56
#
# [12875 rows x 12 columns]

# %%
apple_data_raw = pd.read_csv('./applemobilitytrends-2021-05-07.csv')
apple_data_raw
# Out:
# C:\Users\tango\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3147: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             geo_type        region transportation_type alternative_name  \
# 0     country/region       Albania             driving              NaN
# 1     country/region       Albania             walking              NaN
# 2     country/region     Argentina             driving              NaN
# 3     country/region     Argentina             walking              NaN
# 4     country/region     Australia             driving               AU
# ...              ...           ...                 ...              ...
# 4686          county   York County             walking              NaN
# 4687          county  Young County             driving              NaN
# 4688          county   Yuba County             driving              NaN
# 4689          county   Yuma County             driving              NaN
# 4690          county   Yuma County             walking              NaN
#
#         sub-region        country  2020-01-13  2020-01-14  2020-01-15  \
# 0              NaN            NaN       100.0       95.30      101.43
# 1              NaN            NaN       100.0      100.68       98.93
# 2              NaN            NaN       100.0       97.07      102.45
# 3              NaN            NaN       100.0       95.11      101.37
# 4              NaN            NaN       100.0      102.98      104.21
# ...            ...            ...         ...         ...         ...
# 4686  Pennsylvania  United States       100.0      110.22      121.82
# 4687         Texas  United States       100.0       98.85       97.76
# 4688    California  United States       100.0      102.98      103.10
# 4689       Arizona  United States       100.0      101.82      106.67
# 4690       Arizona  United States       100.0       95.88       98.97
#
#       2020-01-16  ...  2021-04-28  2021-04-29  2021-04-30  2021-05-01  \
# 0          97.20  ...      105.82      111.41      135.23      182.13
# 1          98.46  ...      137.44      129.98      155.35      169.47
# 2         111.21  ...       62.91       65.26       81.98       78.80
# 3         112.67  ...       57.93       59.52       68.79       58.44
# 4         108.63  ...      115.54      124.86      130.17      104.93
# ...          ...  ...         ...         ...         ...         ...
# 4686      109.72  ...      206.02      181.60      248.07      238.51
# 4687       92.21  ...      140.51      141.73      164.84      155.76
# 4688      114.08  ...      152.78      153.62      177.45      177.48
# 4689      108.93  ...      122.22      133.22      153.75      130.66
# 4690       92.88  ...      166.01      155.62      178.11      153.73
#
#       2021-05-02  2021-05-03  2021-05-04  2021-05-05  2021-05-06  2021-05-07
# 0         172.62      145.75      138.43      132.24      135.06      147.77
# 1         145.97      166.57      162.26      153.39      154.46      172.67
# 2          52.41       54.14       58.74       61.20       65.18       81.05
# 3          40.26       48.24       53.56       56.22       59.23       69.96
# 4         101.50      107.43      109.24      112.59      120.96      130.43
# ...          ...         ...         ...         ...         ...         ...
# 4686      190.28      186.52      199.78      202.04      220.06      235.64
# 4687      139.50      135.37      142.48      143.77      151.56      206.91
# 4688      143.45      145.19      142.44      157.14      145.56      176.05
# 4689      114.16      124.46      116.26      122.82      124.53      151.25
# 4690      118.03      141.55      135.45      144.81      137.85      184.89
#
# [4691 rows x 487 columns]

# %%
#['country/region', 'city', 'sub-region', 'county']
#apple_data_raw[apple_data_raw['geo_type']=='sub-region']['region'].unique()

# %%
Country_in_Interest = ['United States'] #United States Only
traffic_data = apple_data_raw[apple_data_raw['region'].isin(merged_df['location'])]
traffic_data = traffic_data.drop(columns=['geo_type','alternative_name','country'])
traffic_data = traffic_data.groupby('region').mean()

traffic_data = traffic_data.reset_index().melt('region')
traffic_data.columns=['State','Date','Traffic']
traffic_data['Date'] = pd.to_datetime(traffic_data['Date'])
#traffic_data = traffic_data[traffic_data['Country'].isin(Country_in_Interest)]
traffic_data = traffic_data[~traffic_data['Date'].isin(['2020-05-11','2020-05-12', '2021-03-12'])]
traffic_data
# Out:
#                State       Date     Traffic
# 0            Alabama 2020-01-13  100.000000
# 1             Alaska 2020-01-13  100.000000
# 2            Arizona 2020-01-13  100.000000
# 3           Arkansas 2020-01-13  100.000000
# 4         California 2020-01-13  100.000000
# ...              ...        ...         ...
# 24045       Virginia 2021-05-07  132.806667
# 24046     Washington 2021-05-07  142.310000
# 24047  West Virginia 2021-05-07  161.435000
# 24048      Wisconsin 2021-05-07  180.290000
# 24049        Wyoming 2021-05-07  263.280000
#
# [23900 rows x 3 columns]

# %%
merged_df = merged_df.merge(traffic_data,how='inner',left_on=['date','location'],right_on=['Date','State'])

# %%
merged_df = merged_df[['date','location','Confirmed','Average Temperature (deg F)','Traffic']]
merged_df = merged_df[merged_df['location'].str.strip()!='']
merged_df
# Out:
#             date       location  Confirmed  Average Temperature (deg F)  \
# 0     2020-01-25       Illinois        1.0                    33.600000
# 1     2020-01-26       Illinois        1.0                    33.580000
# 2     2020-01-26     California        2.0                    45.983280
# 3     2020-01-27       Illinois        1.0                    30.400000
# 4     2020-01-27     California        2.0                    45.399615
# ...          ...            ...        ...                          ...
# 12784 2020-12-31       Virginia   349584.0                    48.800000
# 12785 2020-12-31     Washington   246752.0                    37.500000
# 12786 2020-12-31  West Virginia    85334.0                    43.600000
# 12787 2020-12-31      Wisconsin   520438.0                    19.240000
# 12788 2020-12-31        Wyoming    44409.0                    23.466667
#
#           Traffic
# 0      123.930000
# 1       85.736667
# 2       89.240000
# 3       96.593333
# 4      102.456667
# ...           ...
# 12784   94.766667
# 12785   87.850000
# 12786  118.225000
# 12787  121.426667
# 12788  189.310000
#
# [12789 rows x 5 columns]

# %%
charts = []
colors=['black','red','blue']
for i,y_ in enumerate(['Confirmed','Average Temperature (deg F)','Traffic']):
    chart = alt.Chart().mark_line(color=colors[i]).encode(
        y = alt.Y(y_),
        x = 'date')
    charts.append(chart)
charts = [charts[0],alt.layer(charts[1],charts[2]).resolve_scale(y='shared')]
alt.data_transformers.disable_max_rows() 
alt.layer(*charts,data=merged_df).properties(width=200,height=200).resolve_scale(y='independent').facet('location',columns=3).resolve_scale(x='shared',y='independent')
# Out:
# alt.FacetChart(...)

# %%
alt.data_transformers.disable_max_rows()
#scatter = alt.Chart(loc_timeseries.reset_index()).mark_point().encode(x='date:T',y='mean(Average Temperature (deg F))')
#print(loc_timeseries.reset_index().groupby('date').mean().reset_index())
mean_temp = alt.Chart(merged_df.reset_index().groupby('date').mean().reset_index()).transform_window(rolling_temp='mean(Average Temperature (deg F))',frame=[-7,7]
                                                               ).mark_line(color='red',size=1).encode(
                                                                    x='date:T',
                                                                    y=alt.Y('rolling_temp:Q'),
                                                                    )#,scale=alt.Scale(domain=[20,80])))
mean_covid = alt.Chart(merged_df.reset_index().groupby('date').mean().reset_index()).transform_window(rolling_confirmed='mean(Confirmed)',frame=[-7,7]
                                                               ).mark_line(color='black',size=1).encode(
                                                                    x='date:T',
                                                                    y=alt.Y('rolling_confirmed:Q'),
                                                                    )

mean_traffic = alt.Chart(merged_df.reset_index().groupby('date').mean().reset_index()).transform_window(rolling_traffic='mean(Traffic)',frame=[-7,7]
                                                               ).mark_line(color='blue',size=1).encode(
                                                                    x='date:T',
                                                                    y=alt.Y('rolling_traffic:Q'),
                                                                    )
alt.layer((mean_temp+mean_traffic).properties(width=400).resolve_scale(y='shared',x='shared'),mean_covid).resolve_scale(y='independent',x='shared').properties(width=400)
# Out:
# alt.LayerChart(...)

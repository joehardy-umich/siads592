# %%
import os
import pandas as pd
import altair as alt
import numpy as np

# %%
weather_data = pd.read_csv('clean_weather_data.csv')
covid_data = pd.read_csv('clean_covid_data.csv')

# %%
weather_data = weather_data.drop(weather_data.columns[0],axis=1)
covid_data = covid_data.drop(covid_data.columns[0],axis=1)

# %%
covid_data
# Out:
#           SNo ObservationDate Province/State Country/Region  \
# 0          32      2020-01-22     Washington             US
# 1          71      2020-01-23     Washington             US
# 2         120      2020-01-24     Washington             US
# 3         162      2020-01-25     Washington             US
# 4         163      2020-01-25       Illinois             US
# ...       ...             ...            ...            ...
# 14870  192089      2020-12-31       Virginia             US
# 14871  192098      2020-12-31     Washington             US
# 14872  192101      2020-12-31  West Virginia             US
# 14873  192103      2020-12-31      Wisconsin             US
# 14874  192104      2020-12-31        Wyoming             US
#
#                Last Update  Confirmed  Deaths  Recovered
# 0          1/22/2020 17:00        1.0     0.0        0.0
# 1            1/23/20 17:00        1.0     0.0        0.0
# 2            1/24/20 17:00        1.0     0.0        0.0
# 3            1/25/20 17:00        1.0     0.0        0.0
# 4            1/25/20 17:00        1.0     0.0        0.0
# ...                    ...        ...     ...        ...
# 14870  2021-04-02 15:13:53   349584.0  5032.0        0.0
# 14871  2021-04-02 15:13:53   246752.0  3461.0        0.0
# 14872  2021-04-02 15:13:53    85334.0  1338.0        0.0
# 14873  2021-04-02 15:13:53   520438.0  5242.0        0.0
# 14874  2021-04-02 15:13:53    44409.0   438.0        0.0
#
# [14875 rows x 8 columns]

# %%
weather_data
# Out:
#              date  Average Temperature (deg F) location     fids
# 0      2020-03-10                    61.769231  Alabama  FIPS:01
# 1      2020-03-11                    63.076923  Alabama  FIPS:01
# 2      2020-03-12                    67.384615  Alabama  FIPS:01
# 3      2020-03-13                    66.538462  Alabama  FIPS:01
# 4      2020-03-14                    66.153846  Alabama  FIPS:01
# ...           ...                          ...      ...      ...
# 13001  2020-12-25                    27.888889  Wyoming  FIPS:56
# 13002  2020-12-26                    29.411765  Wyoming  FIPS:56
# 13003  2020-12-27                    21.461538  Wyoming  FIPS:56
# 13004  2020-12-30                    14.727273  Wyoming  FIPS:56
# 13005  2020-12-31                    23.466667  Wyoming  FIPS:56
#
# [13006 rows x 4 columns]

# %%
#We can compare average temperature to confirmed cases, deaths, and recoveries
merged_df = covid_data.merge(weather_data,how='inner',left_on=['ObservationDate','Province/State'],right_on=['date','location'])
merged_df
# Out:
#           SNo ObservationDate Province/State Country/Region  \
# 0         163      2020-01-25       Illinois             US
# 1         208      2020-01-26       Illinois             US
# 2         209      2020-01-26     California             US
# 3         256      2020-01-27       Illinois             US
# 4         257      2020-01-27     California             US
# ...       ...             ...            ...            ...
# 12870  192089      2020-12-31       Virginia             US
# 12871  192098      2020-12-31     Washington             US
# 12872  192101      2020-12-31  West Virginia             US
# 12873  192103      2020-12-31      Wisconsin             US
# 12874  192104      2020-12-31        Wyoming             US
#
#                Last Update  Confirmed  Deaths  Recovered        date  \
# 0            1/25/20 17:00        1.0     0.0        0.0  2020-01-25
# 1            1/26/20 16:00        1.0     0.0        0.0  2020-01-26
# 2            1/26/20 16:00        2.0     0.0        0.0  2020-01-26
# 3            1/27/20 23:59        1.0     0.0        0.0  2020-01-27
# 4            1/27/20 23:59        2.0     0.0        0.0  2020-01-27
# ...                    ...        ...     ...        ...         ...
# 12870  2021-04-02 15:13:53   349584.0  5032.0        0.0  2020-12-31
# 12871  2021-04-02 15:13:53   246752.0  3461.0        0.0  2020-12-31
# 12872  2021-04-02 15:13:53    85334.0  1338.0        0.0  2020-12-31
# 12873  2021-04-02 15:13:53   520438.0  5242.0        0.0  2020-12-31
# 12874  2021-04-02 15:13:53    44409.0   438.0        0.0  2020-12-31
#
#        Average Temperature (deg F)       location     fids
# 0                        33.600000       Illinois  FIPS:17
# 1                        33.580000       Illinois  FIPS:17
# 2                        45.983280     California  FIPS:06
# 3                        30.400000       Illinois  FIPS:17
# 4                        45.399615     California  FIPS:06
# ...                            ...            ...      ...
# 12870                    48.800000       Virginia  FIPS:51
# 12871                    37.500000     Washington  FIPS:53
# 12872                    43.600000  West Virginia  FIPS:54
# 12873                    19.240000      Wisconsin  FIPS:55
# 12874                    23.466667        Wyoming  FIPS:56
#
# [12875 rows x 12 columns]

# %%
covid_ts = merged_df[['date','location','Confirmed']]
tavg_ts = merged_df[['date','location','Average Temperature (deg F)']]

# %%
covid_chart = alt.Chart(covid_ts.groupby('date').sum().reset_index()).mark_line(color='black').encode(
        x=alt.X('date:T',axis=alt.Axis(tickMinStep=180)),y='Confirmed')
tavg_chart = alt.Chart(tavg_ts.groupby('date').mean().reset_index()).mark_line(color='red').encode(
        x=alt.X('date:T',axis=alt.Axis(tickMinStep=180)),y=alt.Y('Average Temperature (deg F)',axis=alt.Axis(titleColor='red')))

(covid_chart+tavg_chart).properties(width=500).resolve_scale(y='independent')
# Out:
# alt.LayerChart(...)

# %%
charts = []
for location in sorted(covid_ts['location'].unique()):
    covid_chart = alt.Chart(covid_ts[covid_ts['location']==location]).mark_line(color='black').encode(
        x=alt.X('date:T',axis=alt.Axis(tickMinStep=180)),y='Confirmed')
    tavg_chart = alt.Chart(tavg_ts[tavg_ts['location']==location]).mark_line(color='red').encode(
        x=alt.X('date:T',axis=alt.Axis(tickMinStep=180)),y=alt.Y('Average Temperature (deg F)',axis=alt.Axis(titleColor='red')))
    charts.append((covid_chart+tavg_chart).properties(width=500,title=location).resolve_scale(y='independent'))
alt.vconcat(*charts)
# Out:
# alt.VConcatChart(...)
